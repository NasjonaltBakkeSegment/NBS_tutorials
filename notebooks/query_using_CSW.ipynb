# %% [markdown]
# ## How to Query satellittdata.no Using CSW
#
# The **Catalogue Service for the Web (CSW)** is an **Open Geospatial Consortium (OGC)** standard that enables structured querying and discovery of geospatial metadata over the web. It provides a standardised interface to search metadata catalogues using parameters such as keywords, spatial extent, and time. This tutorial demonstrates how to use CSW to query datasets hosted on [satellittdata.no](https://www.satellittdata.no/), Norway’s national satellite data portal. With Python tools, we can efficiently discover and retrieve metadata about available Earth observation products.
#
# ## Importing libraries
#
# Let's begin by importing the Python libraries we’ll use in this session.
#
# If you don’t already have **OWSLib** installed, you may need to run:
#
# ```bash
# pip install owslib
# ```
#
# Now we can import the libraries

# %%
from owslib import fes
from owslib.csw import CatalogueServiceWeb
from datetime import datetime, timedelta
import pytz

# %% [markdown]
# ## Defining functions
#
# Let's now define some functions that will help us use CSW to query. We will use these functions to perform a range of queries in the next section.

# %%
def _get_csw_connection(endpoint):
    """ Connect to CSW server
    """
    csw = CatalogueServiceWeb(endpoint, timeout=60)
    return csw

def _get_freetxt_search(kw_names):
    """
    Retuns a CSW search object based on input string
    """
    freetxt_filt = fes.PropertyIsLike('apiso:AnyText',  literal=('%s' % kw_names),
                                      escapeChar="\\", singleChar=".",
                                      wildCard="*", matchCase="True")
    return freetxt_filt

def _get_csw_records(csw, filter_list, pagesize=10, maxrecords=1):
    """
    Iterate `maxrecords`/`pagesize` times until the requested value in
    `maxrecords` is reached.
    """
    csw_records = {}
    startposition = 0
    nextrecord = getattr(csw, "results", 1)
    while nextrecord != 0:
        csw.getrecords2(
            constraints=filter_list,
            startposition=startposition,
            maxrecords=pagesize,
            outputschema="http://www.opengis.net/cat/csw/2.0.2",
            esn='full',
        )
        print(csw.results)
        csw_records.update(csw.records)
        if csw.results["nextrecord"] == 0:
            break
        startposition += pagesize + 1  # Last one is included.
        if startposition >= maxrecords:
            break
    csw.records.update(csw_records)

def _fes_date_filter(start, stop, constraint="overlaps"):
    """
    Take datetime-like objects and returns a fes filter for date range
    (begin and end inclusive).
    NOTE: Truncates the minutes!!!
    """
    start = start.strftime("%Y-%m-%d %H:00")
    stop = stop.strftime("%Y-%m-%d %H:00")
    if constraint == "overlaps":
        propertyname = "apiso:TempExtent_begin"
        begin = fes.PropertyIsLessThanOrEqualTo(propertyname=propertyname, literal=stop)
        propertyname = "apiso:TempExtent_end"
        end = fes.PropertyIsGreaterThanOrEqualTo(
            propertyname=propertyname, literal=start
        )
    elif constraint == "within":
        propertyname = "apiso:TempExtent_begin"
        begin = fes.PropertyIsGreaterThanOrEqualTo(
            propertyname=propertyname, literal=start
        )
        propertyname = "apiso:TempExtent_end"
        end = fes.PropertyIsLessThanOrEqualTo(propertyname=propertyname, literal=stop)
    else:
        raise NameError("Unrecognized constraint {}".format(constraint))
    return begin, end

# %% [markdown]
# ## Querying using CSW
#
# Let's first define the parameters we want to use for querying.

# %%
##### Main start here ##############
endpoint='https://nbs.csw.met.no'
bbox = [-80, 60.00, 10, 90.00]
start = datetime(2025, 3, 5, 00, 00, 00).replace(tzinfo=pytz.utc)
stop = datetime(2025, 6, 15, 00, 00, 00).replace(tzinfo=pytz.utc)
kw_names = 'Sentinel-1'
#crs='urn:ogc:def:crs:OGC:1.3:CRS84'



crs='urn:x-ogc:def:crs:EPSG:6.18:4326'

constraints = []
# connect to endpoint
try:
    csw = _get_csw_connection(endpoint)
except Exception as e:
    print("Exception: %s" % str(e))

if kw_names:
    freetxt_filt = _get_freetxt_search(kw_names)
    constraints.append(freetxt_filt)

if all(v is not None for v in [start, stop]):
    begin, end = _fes_date_filter(start, stop)
    constraints.append(begin)
    constraints.append(end)

if bbox:
     bbox_crs = fes.BBox(bbox, crs=crs)
     constraints.append(bbox_crs)

if len(constraints) >= 2:
    filter_list = [fes.And(constraints)]
else:
    filter_list = constraints


_get_csw_records(csw, filter_list, pagesize=10, maxrecords=100)
url_opendap = []

#print(len(csw.records))
for key, value in list(csw.records.items()):
    for ref in value.references:
        print(ref)
        if ref['scheme'] == 'OPeNDAP:OPeNDAP':
            #if '/2024/' in ref['url']:
            #print(ref['url'])
            url_opendap.append(ref['url'])
# Out:
# {'matches': 44, 'returned': 10, 'nextrecord': 11}
# {'matches': 44, 'returned': 10, 'nextrecord': 21}
# {'matches': 44, 'returned': 10, 'nextrecord': 32}
# {'matches': 44, 'returned': 10, 'nextrecord': 43}
# {'matches': 44, 'returned': 1, 'nextrecord': 0}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/16/IW/S1A_IW_GRDM_1SDV_20250316T062111_20250316T062138_058326_0735E5_95DE.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/7a91b2bf-e202-44c3-a89e-e7bdc79ec8e9/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/16/IW/S1A_IW_GRDM_1SDV_20250316T062111_20250316T062138_058326_0735E5_95DE.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/15/IW/S1A_IW_GRDM_1SDV_20250315T165625_20250315T165652_058318_073595_4DC0.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/1e294e5b-3d20-4948-b9d4-e678f615c8c8/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/15/IW/S1A_IW_GRDM_1SDV_20250315T165625_20250315T165652_058318_073595_4DC0.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/14/IW/S1A_IW_GRDM_1SDV_20250314T161707_20250314T161734_058303_07350B_80B6.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/4683f677-8260-43e7-8c2d-60801d74464b/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/14/IW/S1A_IW_GRDM_1SDV_20250314T161707_20250314T161734_058303_07350B_80B6.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/13/IW/S1A_IW_GRDM_1SDV_20250313T171235_20250313T171302_058289_073479_290D.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/17054585-e6f9-4c35-abef-fcfaae3b266b/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/13/IW/S1A_IW_GRDM_1SDV_20250313T171235_20250313T171302_058289_073479_290D.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/15/IW/S1A_IW_GRDM_1SDV_20250315T165600_20250315T165627_058318_073595_92D3.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/dbbbf627-d6d1-4e5d-8981-0fe54991a3ad/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/15/IW/S1A_IW_GRDM_1SDV_20250315T165600_20250315T165627_058318_073595_92D3.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/15/EW/S1A_EW_GRDM_1SDH_20250315T183645_20250315T183746_058319_0735A1_8AC3.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/1ca89c4f-4f80-4238-b328-4f32d580e7b0/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/15/EW/S1A_EW_GRDM_1SDH_20250315T183645_20250315T183746_058319_0735A1_8AC3.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/15/IW/S1A_IW_GRDM_1SDV_20250315T053921_20250315T053948_058311_073551_881D.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/38519b60-bd74-4fb3-9c2f-14f97977f8be/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/15/IW/S1A_IW_GRDM_1SDV_20250315T053921_20250315T053948_058311_073551_881D.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/15/IW/S1A_IW_GRDM_1SDV_20250315T053831_20250315T053858_058311_073551_3A6C.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/32479af3-caa5-4b6d-be94-3c13d554c392/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/15/IW/S1A_IW_GRDM_1SDV_20250315T053831_20250315T053858_058311_073551_3A6C.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/15/IW/S1A_IW_GRDM_1SDV_20250315T165650_20250315T165717_058318_073595_D153.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/331ede78-708b-4154-853f-19b7091e8ff6/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/15/IW/S1A_IW_GRDM_1SDV_20250315T165650_20250315T165717_058318_073595_D153.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/13/IW/S1A_IW_GRDM_1SDV_20250313T171056_20250313T171123_058289_073479_8CC5.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/425589eb-01c8-4c89-ab25-5d09f41a38c3/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/13/IW/S1A_IW_GRDM_1SDV_20250313T171056_20250313T171123_058289_073479_8CC5.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/13/IW/S1A_IW_GRDM_1SDV_20250313T055449_20250313T055516_058282_07342C_9E0E.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/8e227e5f-38f7-449a-88e5-55ad6efe2bf0/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/13/IW/S1A_IW_GRDM_1SDV_20250313T055449_20250313T055516_058282_07342C_9E0E.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/14/EW/S1A_EW_GRDM_1SDH_20250314T175455_20250314T175602_058304_073515_17D5.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/b3ff4ff0-4fb7-4eae-a610-c5a8870607a6/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/14/EW/S1A_EW_GRDM_1SDH_20250314T175455_20250314T175602_058304_073515_17D5.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/13/IW/S1A_IW_GRDM_1SDV_20250313T055514_20250313T055541_058282_07342C_6975.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/b5eac03c-ce74-4cfd-9fa6-46e5996188e4/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/13/IW/S1A_IW_GRDM_1SDV_20250313T055514_20250313T055541_058282_07342C_6975.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/13/IW/S1A_IW_GRDM_1SDV_20250313T055334_20250313T055401_058282_07342C_8E30.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/95297997-ac51-4e83-9a82-d86e0eb61ad2/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/13/IW/S1A_IW_GRDM_1SDV_20250313T055334_20250313T055401_058282_07342C_8E30.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/15/IW/S1A_IW_GRDM_1SDV_20250315T165445_20250315T165512_058318_073595_7A72.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/8415a9c9-e375-4259-89e7-830901fa42e3/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/15/IW/S1A_IW_GRDM_1SDV_20250315T165445_20250315T165512_058318_073595_7A72.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/13/IW/S1A_IW_GRDH_1SDV_20250313T171216_20250313T171336_058289_073479_C7F6.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/8882034d-15ec-42e3-81ab-9d5e93853dc8/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/13/IW/S1A_IW_GRDH_1SDV_20250313T171216_20250313T171336_058289_073479_C7F6.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/13/IW/S1A_IW_GRDH_1SDV_20250313T055434_20250313T055556_058282_07342C_FE48.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/2a65562b-118e-4e98-9d20-bdddb97489a6/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/13/IW/S1A_IW_GRDH_1SDV_20250313T055434_20250313T055556_058282_07342C_FE48.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/14/IW/S1A_IW_GRDM_1SDV_20250314T161713_20250314T161737_058303_07350B_F588.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/5589a00c-b1fe-428f-9da5-050e6e6f4086/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/14/IW/S1A_IW_GRDM_1SDV_20250314T161713_20250314T161737_058303_07350B_F588.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/14/EW/S1A_EW_GRDM_1SDH_20250314T175555_20250314T175702_058304_073515_FE8E.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/50c60392-38ac-4f53-9546-a9a58ebf3de6/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/14/EW/S1A_EW_GRDM_1SDH_20250314T175555_20250314T175702_058304_073515_FE8E.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/15/EW/S1A_EW_GRDH_1SDH_20250315T071444_20250315T071651_058312_07355E_3373.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/55e9845f-f502-4581-89bf-a6f078a35067/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/15/EW/S1A_EW_GRDH_1SDH_20250315T071444_20250315T071651_058312_07355E_3373.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/15/IW/S1A_IW_GRDM_1SDV_20250315T053855_20250315T053922_058311_073551_E9E6.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/6e611b4b-8fb4-4ac9-81b1-30392ed7d37b/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/15/IW/S1A_IW_GRDM_1SDV_20250315T053855_20250315T053922_058311_073551_E9E6.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/13/IW/S1A_IW_GRDM_1SDV_20250313T055605_20250313T055632_058282_07342C_BCA4.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/178c6a61-bfb2-408f-a4ce-9c29af5ebae6/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/13/IW/S1A_IW_GRDM_1SDV_20250313T055605_20250313T055632_058282_07342C_BCA4.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/14/EW/S1A_EW_GRDH_1SDH_20250314T175416_20250314T175624_058304_073515_B48C.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/6bddbe06-4c58-4739-bdd3-39fcfbeb118b/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/14/EW/S1A_EW_GRDH_1SDH_20250314T175416_20250314T175624_058304_073515_B48C.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/13/IW/S1A_IW_GRDM_1SDV_20250313T055539_20250313T055606_058282_07342C_D3C7.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/6cbf2166-cf11-4ce9-8263-b5a37618bf42/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/13/IW/S1A_IW_GRDM_1SDV_20250313T055539_20250313T055606_058282_07342C_D3C7.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/13/IW/S1A_IW_GRDM_1SDV_20250313T055630_20250313T055657_058282_07342C_A8F8.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/5e26c1c6-d173-41f7-9911-bd1e13574507/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/13/IW/S1A_IW_GRDM_1SDV_20250313T055630_20250313T055657_058282_07342C_A8F8.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/13/IW/S1A_IW_GRDM_1SDV_20250313T171210_20250313T171237_058289_073479_A132.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/73d01f2d-5dc7-44f2-9e51-952f1c9abd16/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/13/IW/S1A_IW_GRDM_1SDV_20250313T171210_20250313T171237_058289_073479_A132.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/15/EW/S1A_EW_GRDM_1SDH_20250315T071345_20250315T071452_058312_07355E_5EFE.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/e47e7546-c237-41ed-b689-224a253ee134/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/15/EW/S1A_EW_GRDM_1SDH_20250315T071345_20250315T071452_058312_07355E_5EFE.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/15/IW/S1A_IW_GRDM_1SDV_20250315T165420_20250315T165447_058318_073595_275F.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/f1549cc2-d7e8-4d68-bc0b-d5c45de9c26c/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/15/IW/S1A_IW_GRDM_1SDV_20250315T165420_20250315T165447_058318_073595_275F.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/15/IW/S1A_IW_GRDM_1SDV_20250315T053946_20250315T054013_058311_073551_6C95.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/f1e58644-c297-49c4-bd64-440e7bf7f277/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/15/IW/S1A_IW_GRDM_1SDV_20250315T053946_20250315T054013_058311_073551_6C95.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/13/IW/S1A_IW_GRDM_1SDV_20250313T055400_20250313T055427_058282_07342C_8F87.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/ff50279a-0419-4991-b536-de2bd21b40bc/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/13/IW/S1A_IW_GRDM_1SDV_20250313T055400_20250313T055427_058282_07342C_8F87.xml'}
# {'scheme': 'OPeNDAP:OPeNDAP', 'url': 'https://nbstds.met.no/thredds/dodsC/NBS/S1A/2025/03/13/IW/S1A_IW_GRDM_1SDV_20250313T055309_20250313T055336_058282_07342C_BCF1.nc'}
# {'scheme': 'OGC:WMS', 'url': 'https://adc-wms.met.no/get_wms/529c74fd-f5a8-40e6-9e65-ca6eac9bb88a/wms'}
# {'scheme': 'WWW:DOWNLOAD-1.0-http--download', 'url': 'https://nbstds.met.no/thredds/fileServer/nbsArchive/S1A/2025/03/13/IW/S1A_IW_GRDM_1SDV_20250313T055309_20250313T055336_058282_07342C_BCF1.xml'}
